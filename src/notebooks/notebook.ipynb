# %%
import os
import sys
import numpy as np
import numpy.typing as npt
from typing import List, Tuple
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import python_modules.Server as Server

# %%
help(Server)
# Out:
# Help on module python_modules.Server in python_modules:
#
# NAME
#     python_modules.Server
#
# SUBMODULES
#     GenericSecurities
#
# CLASSES
#     pybind11_builtins.pybind11_object(builtins.object)
#         CancelOrder
#         IPortfolioManager
#         ISecurity
#         ISimulation
#             GenericSimulation
#         ItemsView
#         KeysView
#         LimitOrder
#         LimitOrderList
#         OrderSide
#         PriceDepthMap
#         SimulationStepResult
#         Transaction
#         ValuesView
#
#     class CancelOrder(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      CancelOrder
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(...)
#      |      __init__(self: python_modules.Server.CancelOrder) -> None
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  order_id
#      |
#      |  user_id
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) class method of pybind11_builtins.pybind11_object
#      |      Create and return a new object.  See help(type) for accurate signature.
#
#     class GenericSimulation(ISimulation)
#      |  Method resolution order:
#      |      GenericSimulation
#      |      ISimulation
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(...)
#      |      __init__(self: python_modules.Server.GenericSimulation, arg0: dict[str, python_modules.Server.ISecurity], arg1: typing.SupportsFloat, arg2: typing.SupportsInt) -> None
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from ISimulation:
#      |
#      |  add_user(...)
#      |      add_user(self: python_modules.Server.ISimulation, username: str) -> int
#      |
#      |  do_simulation_step(...)
#      |      do_simulation_step(self: python_modules.Server.ISimulation) -> python_modules.Server.SimulationStepResult
#      |
#      |  get_N(...)
#      |      get_N(self: python_modules.Server.ISimulation) -> int
#      |
#      |  get_T(...)
#      |      get_T(self: python_modules.Server.ISimulation) -> float
#      |
#      |  get_all_open_user_orders(...)
#      |      get_all_open_user_orders(self: python_modules.Server.ISimulation, user_id: typing.SupportsInt, security_id: typing.SupportsInt) -> set[int]
#      |
#      |  get_all_tickers(...)
#      |      get_all_tickers(self: python_modules.Server.ISimulation) -> list[str]
#      |
#      |  get_ask_count(...)
#      |      get_ask_count(self: python_modules.Server.ISimulation, security_id: typing.SupportsInt) -> int
#      |
#      |  get_bid_count(...)
#      |      get_bid_count(self: python_modules.Server.ISimulation, security_id: typing.SupportsInt) -> int
#      |
#      |  get_cumulative_book_depth(...)
#      |      get_cumulative_book_depth(self: python_modules.Server.ISimulation, security_id: typing.SupportsInt) -> tuple[dict[float, float], dict[float, float]]
#      |
#      |  get_dt(...)
#      |      get_dt(self: python_modules.Server.ISimulation) -> float
#      |
#      |  get_order_book(...)
#      |      get_order_book(self: python_modules.Server.ISimulation, security_id: typing.SupportsInt) -> tuple[list[python_modules.Server.LimitOrder], list[python_modules.Server.LimitOrder]]
#      |
#      |  get_securities_count(...)
#      |      get_securities_count(self: python_modules.Server.ISimulation) -> int
#      |
#      |  get_security_id(...)
#      |      get_security_id(self: python_modules.Server.ISimulation, security_ticker: str) -> int
#      |
#      |  get_security_ticker(...)
#      |      get_security_ticker(self: python_modules.Server.ISimulation, security_id: typing.SupportsInt) -> str
#      |
#      |  get_t(...)
#      |      get_t(self: python_modules.Server.ISimulation) -> float
#      |
#      |  get_tick(...)
#      |      get_tick(self: python_modules.Server.ISimulation) -> int
#      |
#      |  get_top_ask(...)
#      |      get_top_ask(self: python_modules.Server.ISimulation, security_id: typing.SupportsInt) -> python_modules.Server.LimitOrder
#      |
#      |  get_top_bid(...)
#      |      get_top_bid(self: python_modules.Server.ISimulation, security_id: typing.SupportsInt) -> python_modules.Server.LimitOrder
#      |
#      |  get_user_count(...)
#      |      get_user_count(self: python_modules.Server.ISimulation) -> int
#      |
#      |  get_user_id_to_username(...)
#      |      get_user_id_to_username(self: python_modules.Server.ISimulation) -> dict[int, str]
#      |
#      |  reset_simulation(...)
#      |      reset_simulation(self: python_modules.Server.ISimulation) -> None
#      |
#      |  submit_cancel_order(...)
#      |      submit_cancel_order(self: python_modules.Server.ISimulation, user_id: typing.SupportsInt, security_id: typing.SupportsInt, order_id: typing.SupportsInt) -> None
#      |
#      |  submit_limit_order(...)
#      |      submit_limit_order(self: python_modules.Server.ISimulation, user_id: typing.SupportsInt, security_id: typing.SupportsInt, side: python_modules.Server.OrderSide, price: typing.SupportsFloat, volume: typing.SupportsFloat) -> int
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) class method of pybind11_builtins.pybind11_object
#      |      Create and return a new object.  See help(type) for accurate signature.
#
#     class IPortfolioManager(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      IPortfolioManager
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(...)
#      |      __init__(self: python_modules.Server.IPortfolioManager) -> None
#      |
#      |  add_to_security(...)
#      |      add_to_security(self: python_modules.Server.IPortfolioManager, user_id: typing.SupportsInt, security_id: typing.SupportsInt, addition: typing.SupportsFloat) -> float
#      |
#      |  add_to_two_securities(...)
#      |      add_to_two_securities(self: python_modules.Server.IPortfolioManager, user_id: typing.SupportsInt, security_1: typing.SupportsInt, addition_1: typing.SupportsFloat, security_2: typing.SupportsInt, addition_2: typing.SupportsFloat) -> tuple[float, float]
#      |
#      |  get_portfolio_table(...)
#      |      get_portfolio_table(self: python_modules.Server.IPortfolioManager) -> list[list[float]]
#      |
#      |  multiply_and_add_1_to_2(...)
#      |      multiply_and_add_1_to_2(self: python_modules.Server.IPortfolioManager, user_id: typing.SupportsInt, security_1: typing.SupportsInt, security_2: typing.SupportsInt, multiply: typing.SupportsFloat) -> float
#      |
#      |  multiply_and_add_1_to_2_and_set_1(...)
#      |      multiply_and_add_1_to_2_and_set_1(self: python_modules.Server.IPortfolioManager, user_id: typing.SupportsInt, security_1: typing.SupportsInt, security_2: typing.SupportsInt, multiply: typing.SupportsFloat, set_value: typing.SupportsFloat) -> float
#      |
#      |  reset_user_portfolio(...)
#      |      reset_user_portfolio(self: python_modules.Server.IPortfolioManager, user_id: typing.SupportsInt) -> None
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) class method of pybind11_builtins.pybind11_object
#      |      Create and return a new object.  See help(type) for accurate signature.
#
#     class ISecurity(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      ISecurity
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(...)
#      |      __init__(self: python_modules.Server.ISecurity) -> None
#      |
#      |  after_step(...)
#      |      after_step(self: python_modules.Server.ISecurity, simulation: ISimulation, portfolio: IPortfolioManager) -> None
#      |
#      |  before_step(...)
#      |      before_step(self: python_modules.Server.ISecurity, simulation: ISimulation, portfolio: IPortfolioManager) -> None
#      |
#      |  is_tradeable(...)
#      |      is_tradeable(self: python_modules.Server.ISecurity) -> bool
#      |
#      |  on_simulation_end(...)
#      |      on_simulation_end(self: python_modules.Server.ISecurity, simulation: ISimulation, portfolio: IPortfolioManager) -> None
#      |
#      |  on_simulation_start(...)
#      |      on_simulation_start(self: python_modules.Server.ISecurity, simulation: ISimulation, portfolio: IPortfolioManager) -> None
#      |
#      |  on_trade_executed(...)
#      |      on_trade_executed(self: python_modules.Server.ISecurity, simulation: ISimulation, portfolio: IPortfolioManager, buyer_id: typing.SupportsInt, seller_id: typing.SupportsInt, transacted_price: typing.SupportsFloat, transacted_volume: typing.SupportsFloat) -> None
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) class method of pybind11_builtins.pybind11_object
#      |      Create and return a new object.  See help(type) for accurate signature.
#
#     class ISimulation(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      ISimulation
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(...)
#      |      __init__(self: python_modules.Server.ISimulation, securities: dict[str, python_modules.Server.ISecurity], T: typing.SupportsFloat, N: typing.SupportsInt) -> None
#      |
#      |  add_user(...)
#      |      add_user(self: python_modules.Server.ISimulation, username: str) -> int
#      |
#      |  do_simulation_step(...)
#      |      do_simulation_step(self: python_modules.Server.ISimulation) -> python_modules.Server.SimulationStepResult
#      |
#      |  get_N(...)
#      |      get_N(self: python_modules.Server.ISimulation) -> int
#      |
#      |  get_T(...)
#      |      get_T(self: python_modules.Server.ISimulation) -> float
#      |
#      |  get_all_open_user_orders(...)
#      |      get_all_open_user_orders(self: python_modules.Server.ISimulation, user_id: typing.SupportsInt, security_id: typing.SupportsInt) -> set[int]
#      |
#      |  get_all_tickers(...)
#      |      get_all_tickers(self: python_modules.Server.ISimulation) -> list[str]
#      |
#      |  get_ask_count(...)
#      |      get_ask_count(self: python_modules.Server.ISimulation, security_id: typing.SupportsInt) -> int
#      |
#      |  get_bid_count(...)
#      |      get_bid_count(self: python_modules.Server.ISimulation, security_id: typing.SupportsInt) -> int
#      |
#      |  get_cumulative_book_depth(...)
#      |      get_cumulative_book_depth(self: python_modules.Server.ISimulation, security_id: typing.SupportsInt) -> tuple[dict[float, float], dict[float, float]]
#      |
#      |  get_dt(...)
#      |      get_dt(self: python_modules.Server.ISimulation) -> float
#      |
#      |  get_order_book(...)
#      |      get_order_book(self: python_modules.Server.ISimulation, security_id: typing.SupportsInt) -> tuple[list[python_modules.Server.LimitOrder], list[python_modules.Server.LimitOrder]]
#      |
#      |  get_securities_count(...)
#      |      get_securities_count(self: python_modules.Server.ISimulation) -> int
#      |
#      |  get_security_id(...)
#      |      get_security_id(self: python_modules.Server.ISimulation, security_ticker: str) -> int
#      |
#      |  get_security_ticker(...)
#      |      get_security_ticker(self: python_modules.Server.ISimulation, security_id: typing.SupportsInt) -> str
#      |
#      |  get_t(...)
#      |      get_t(self: python_modules.Server.ISimulation) -> float
#      |
#      |  get_tick(...)
#      |      get_tick(self: python_modules.Server.ISimulation) -> int
#      |
#      |  get_top_ask(...)
#      |      get_top_ask(self: python_modules.Server.ISimulation, security_id: typing.SupportsInt) -> python_modules.Server.LimitOrder
#      |
#      |  get_top_bid(...)
#      |      get_top_bid(self: python_modules.Server.ISimulation, security_id: typing.SupportsInt) -> python_modules.Server.LimitOrder
#      |
#      |  get_user_count(...)
#      |      get_user_count(self: python_modules.Server.ISimulation) -> int
#      |
#      |  get_user_id_to_username(...)
#      |      get_user_id_to_username(self: python_modules.Server.ISimulation) -> dict[int, str]
#      |
#      |  reset_simulation(...)
#      |      reset_simulation(self: python_modules.Server.ISimulation) -> None
#      |
#      |  submit_cancel_order(...)
#      |      submit_cancel_order(self: python_modules.Server.ISimulation, user_id: typing.SupportsInt, security_id: typing.SupportsInt, order_id: typing.SupportsInt) -> None
#      |
#      |  submit_limit_order(...)
#      |      submit_limit_order(self: python_modules.Server.ISimulation, user_id: typing.SupportsInt, security_id: typing.SupportsInt, side: python_modules.Server.OrderSide, price: typing.SupportsFloat, volume: typing.SupportsFloat) -> int
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) class method of pybind11_builtins.pybind11_object
#      |      Create and return a new object.  See help(type) for accurate signature.
#
#     class ItemsView(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      ItemsView
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __iter__(...)
#      |      __iter__(self: python_modules.Server.ItemsView) -> Iterator
#      |
#      |  __len__(...)
#      |      __len__(self: python_modules.Server.ItemsView) -> int
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __pybind11_module_local_v9_msvc_md_mscver19_debug__ = <capsule object ...
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) class method of pybind11_builtins.pybind11_object
#      |      Create and return a new object.  See help(type) for accurate signature.
#
#     class KeysView(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      KeysView
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __contains__(...)
#      |      __contains__(self: python_modules.Server.KeysView, arg0: object) -> bool
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __iter__(...)
#      |      __iter__(self: python_modules.Server.KeysView) -> Iterator
#      |
#      |  __len__(...)
#      |      __len__(self: python_modules.Server.KeysView) -> int
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __pybind11_module_local_v9_msvc_md_mscver19_debug__ = <capsule object ...
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) class method of pybind11_builtins.pybind11_object
#      |      Create and return a new object.  See help(type) for accurate signature.
#
#     class LimitOrder(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      LimitOrder
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(...)
#      |      __init__(self: python_modules.Server.LimitOrder) -> None
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  order_id
#      |
#      |  price
#      |
#      |  side
#      |
#      |  user_id
#      |
#      |  volume
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) class method of pybind11_builtins.pybind11_object
#      |      Create and return a new object.  See help(type) for accurate signature.
#
#     class LimitOrderList(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      LimitOrderList
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __bool__(...)
#      |      __bool__(self: list[python_modules.Server.LimitOrder]) -> bool
#      |
#      |      Check whether the list is nonempty
#      |
#      |  __delitem__(...)
#      |      __delitem__(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. __delitem__(self: list[python_modules.Server.LimitOrder], arg0: typing.SupportsInt) -> None
#      |
#      |      Delete the list elements at index ``i``
#      |
#      |      2. __delitem__(self: list[python_modules.Server.LimitOrder], arg0: slice) -> None
#      |
#      |      Delete list elements using a slice object
#      |
#      |  __getitem__(...)
#      |      __getitem__(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. __getitem__(self: list[python_modules.Server.LimitOrder], s: slice) -> list[python_modules.Server.LimitOrder]
#      |
#      |      Retrieve list elements using a slice object
#      |
#      |      2. __getitem__(self: list[python_modules.Server.LimitOrder], arg0: typing.SupportsInt) -> python_modules.Server.LimitOrder
#      |
#      |  __init__(...)
#      |      __init__(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. __init__(self: python_modules.Server.LimitOrderList) -> None
#      |
#      |      2. __init__(self: python_modules.Server.LimitOrderList, arg0: list[python_modules.Server.LimitOrder]) -> None
#      |
#      |      Copy constructor
#      |
#      |      3. __init__(self: python_modules.Server.LimitOrderList, arg0: Iterable) -> None
#      |
#      |  __iter__(...)
#      |      __iter__(self: list[python_modules.Server.LimitOrder]) -> Iterator[python_modules.Server.LimitOrder]
#      |
#      |  __len__(...)
#      |      __len__(self: list[python_modules.Server.LimitOrder]) -> int
#      |
#      |  __setitem__(...)
#      |      __setitem__(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. __setitem__(self: list[python_modules.Server.LimitOrder], arg0: typing.SupportsInt, arg1: python_modules.Server.LimitOrder) -> None
#      |
#      |      2. __setitem__(self: list[python_modules.Server.LimitOrder], arg0: slice, arg1: list[python_modules.Server.LimitOrder]) -> None
#      |
#      |      Assign list elements using a slice object
#      |
#      |  append(...)
#      |      append(self: list[python_modules.Server.LimitOrder], x: python_modules.Server.LimitOrder) -> None
#      |
#      |      Add an item to the end of the list
#      |
#      |  clear(...)
#      |      clear(self: list[python_modules.Server.LimitOrder]) -> None
#      |
#      |      Clear the contents
#      |
#      |  extend(...)
#      |      extend(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. extend(self: list[python_modules.Server.LimitOrder], L: list[python_modules.Server.LimitOrder]) -> None
#      |
#      |      Extend the list by appending all the items in the given list
#      |
#      |      2. extend(self: list[python_modules.Server.LimitOrder], L: Iterable) -> None
#      |
#      |      Extend the list by appending all the items in the given list
#      |
#      |  insert(...)
#      |      insert(self: list[python_modules.Server.LimitOrder], i: typing.SupportsInt, x: python_modules.Server.LimitOrder) -> None
#      |
#      |      Insert an item at a given position.
#      |
#      |  pop(...)
#      |      pop(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. pop(self: list[python_modules.Server.LimitOrder]) -> python_modules.Server.LimitOrder
#      |
#      |      Remove and return the last item
#      |
#      |      2. pop(self: list[python_modules.Server.LimitOrder], i: typing.SupportsInt) -> python_modules.Server.LimitOrder
#      |
#      |      Remove and return the item at index ``i``
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) class method of pybind11_builtins.pybind11_object
#      |      Create and return a new object.  See help(type) for accurate signature.
#
#     class OrderSide(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      OrderSide
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __eq__(...)
#      |      __eq__(self: object, other: object, /) -> bool
#      |
#      |  __getstate__(...)
#      |      __getstate__(self: object, /) -> int
#      |
#      |  __hash__(...)
#      |      __hash__(self: object, /) -> int
#      |
#      |  __index__(...)
#      |      __index__(self: python_modules.Server.OrderSide, /) -> int
#      |
#      |  __init__(...)
#      |      __init__(self: python_modules.Server.OrderSide, value: typing.SupportsInt) -> None
#      |
#      |  __int__(...)
#      |      __int__(self: python_modules.Server.OrderSide, /) -> int
#      |
#      |  __ne__(...)
#      |      __ne__(self: object, other: object, /) -> bool
#      |
#      |  __repr__(...)
#      |      __repr__(self: object, /) -> str
#      |
#      |  __setstate__(...)
#      |      __setstate__(self: python_modules.Server.OrderSide, state: typing.SupportsInt, /) -> None
#      |
#      |  __str__(...)
#      |      __str__(self: object, /) -> str
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties defined here:
#      |
#      |  __members__
#      |
#      |  name
#      |      name(self: object, /) -> str
#      |
#      |  value
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  ASK = <OrderSide.ASK: 1>
#      |
#      |  BID = <OrderSide.BID: 0>
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) class method of pybind11_builtins.pybind11_object
#      |      Create and return a new object.  See help(type) for accurate signature.
#
#     class PriceDepthMap(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      PriceDepthMap
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __bool__(...)
#      |      __bool__(self: dict[typing.SupportsFloat, typing.SupportsFloat]) -> bool
#      |
#      |      Check whether the map is nonempty
#      |
#      |  __contains__(...)
#      |      __contains__(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. __contains__(self: dict[typing.SupportsFloat, typing.SupportsFloat], arg0: typing.SupportsFloat) -> bool
#      |
#      |      2. __contains__(self: dict[typing.SupportsFloat, typing.SupportsFloat], arg0: object) -> bool
#      |
#      |  __delitem__(...)
#      |      __delitem__(self: dict[typing.SupportsFloat, typing.SupportsFloat], arg0: typing.SupportsFloat) -> None
#      |
#      |  __getitem__(...)
#      |      __getitem__(self: dict[typing.SupportsFloat, typing.SupportsFloat], arg0: typing.SupportsFloat) -> float
#      |
#      |  __init__(...)
#      |      __init__(self: python_modules.Server.PriceDepthMap) -> None
#      |
#      |  __iter__(...)
#      |      __iter__(self: dict[typing.SupportsFloat, typing.SupportsFloat]) -> Iterator[float]
#      |
#      |  __len__(...)
#      |      __len__(self: dict[typing.SupportsFloat, typing.SupportsFloat]) -> int
#      |
#      |  __repr__(...)
#      |      __repr__(self: dict[typing.SupportsFloat, typing.SupportsFloat]) -> str
#      |
#      |      Return the canonical string representation of this map.
#      |
#      |  __setitem__(...)
#      |      __setitem__(self: dict[typing.SupportsFloat, typing.SupportsFloat], arg0: typing.SupportsFloat, arg1: typing.SupportsFloat) -> None
#      |
#      |  items(...)
#      |      items(self: dict[typing.SupportsFloat, typing.SupportsFloat]) -> python_modules.Server.ItemsView
#      |
#      |  keys(...)
#      |      keys(self: dict[typing.SupportsFloat, typing.SupportsFloat]) -> python_modules.Server.KeysView
#      |
#      |  values(...)
#      |      values(self: dict[typing.SupportsFloat, typing.SupportsFloat]) -> python_modules.Server.ValuesView
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __pybind11_module_local_v9_msvc_md_mscver19_debug__ = <capsule object ...
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) class method of pybind11_builtins.pybind11_object
#      |      Create and return a new object.  See help(type) for accurate signature.
#
#     class SimulationStepResult(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      SimulationStepResult
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  cancelled_orders
#      |
#      |  current_step
#      |
#      |  fully_transacted_orders
#      |
#      |  has_next_step
#      |
#      |  order_book_depth_per_security
#      |
#      |  order_book_per_security
#      |
#      |  partially_transacted_orders
#      |
#      |  portfolios
#      |
#      |  transactions
#      |
#      |  user_id_to_username_map
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) class method of pybind11_builtins.pybind11_object
#      |      Create and return a new object.  See help(type) for accurate signature.
#
#     class Transaction(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      Transaction
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  buyer_id
#      |
#      |  price
#      |
#      |  seller_id
#      |
#      |  volume
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) class method of pybind11_builtins.pybind11_object
#      |      Create and return a new object.  See help(type) for accurate signature.
#
#     class ValuesView(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      ValuesView
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __iter__(...)
#      |      __iter__(self: python_modules.Server.ValuesView) -> Iterator
#      |
#      |  __len__(...)
#      |      __len__(self: python_modules.Server.ValuesView) -> int
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __pybind11_module_local_v9_msvc_md_mscver19_debug__ = <capsule object ...
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) class method of pybind11_builtins.pybind11_object
#      |      Create and return a new object.  See help(type) for accurate signature.
#
# DATA
#     ASK = <OrderSide.ASK: 1>
#     BID = <OrderSide.BID: 0>
#
# FILE
#     c:\ssd-dev\traderrank\src\notebooks\python_modules\server.pyd
